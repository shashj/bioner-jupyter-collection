# %%
# !pip install vllm flash-attn ipython-autotime --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 49.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.2/264.2 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 100.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.7 MB/s eta 0:00:00
# ...

# %%
# !git clone --single-branch --branch deepseek_r1 https://github.com/shashj/bioner-jupyter-collection.git
# Out:
# Cloning into 'bioner-jupyter-collection'...
# remote: Enumerating objects: 406, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 406 (delta 42), reused 44 (delta 35), pack-reused 352 (from 1)
# Receiving objects: 100% (406/406), 2.52 MiB | 14.83 MiB/s, done.
# Resolving deltas: 100% (231/231), done.

# %%
# %cd /content/bioner-jupyter-collection/deepseek/
# Out:
# /content/bioner-jupyter-collection/deepseek

# %%
# !pwd
# Out:
# /content/bioner-jupyter-collection/deepseek

# %%
# !python i2b2_date_eval.py
# Out:
# Streaming output truncated to the last 5000 lines.
# }
# Running date Prompt:  37% 246/669 [44:14<1:05:49,  9.34s/it]
# Processed prompts:   0% 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100% 1/1 [00:14<00:00, 14.28s/it, est. speed input: 138.80 toks/s, output: 67.72 toks/s]
# {
#   "dates": [
#     "03/20/2004",
#     "03/26/2004",
#     "03/26/04",
#     "03/25/04",
#     "03/27/04",
#     "03/26",
#     "03/28/04",
#     "03/30/04",
#     "03/31/04",
#     "04/02/04",
#     "04/03/04",
#     "04/05/04",
#     "04/06/04",
#     "04/08/04",
#     "04/09/04",
#     "08/24/31",
#     "03/22/04",
#     "03/25/04"
#   ]
# }
# Running date Prompt:  37% 247/669 [44:28<1:16:06, 10.82s/it]
# Processed prompts:   0% 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100% 1/1 [00:08<00:00,  8.69s/it, est. speed input: 168.03 toks/s, output: 68.25 toks/s]
# {
#   "dates": [
#     "12/11/96",
# ...
