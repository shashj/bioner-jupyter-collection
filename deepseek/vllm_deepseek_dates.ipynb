# %%
# !pip install vllm
# Out:
# Collecting vllm
#   Downloading vllm-0.7.1-cp38-abi3-manylinux1_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from vllm) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from vllm) (0.2.0)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.26.4)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from vllm) (4.67.1)
# Collecting blake3 (from vllm)
#   Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm) (9.0.0)
# Collecting transformers>=4.48.2 (from vllm)
#   Downloading transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from vllm) (4.25.6)
# Collecting fastapi!=0.113.*,!=0.114.0,>=0.107.0 (from vllm)
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from vllm) (3.11.11)
# Requirement already satisfied: openai>=1.52.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (1.59.9)
# Collecting uvicorn[standard] (from vllm)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.10.6)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.21.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm) (11.1.0)
# Collecting prometheus-fastapi-instrumentator>=7.0.0 (from vllm)
#   Downloading prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting lm-format-enforcer<0.11,>=0.10.9 (from vllm)
#   Downloading lm_format_enforcer-0.10.9-py3-none-any.whl.metadata (17 kB)
# Collecting outlines==0.1.11 (from vllm)
#   Downloading outlines-0.1.11-py3-none-any.whl.metadata (17 kB)
# Collecting lark==1.2.2 (from vllm)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting xgrammar>=0.1.6 (from vllm)
#   Downloading xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from vllm) (4.12.2)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (3.17.0)
# Collecting partial-json-parser (from vllm)
#   Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm) (24.0.1)
# Collecting msgspec (from vllm)
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting gguf==0.10.0 (from vllm)
#   Downloading gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from vllm) (8.6.1)
# Collecting mistral_common>=1.5.0 (from mistral_common[opencv]>=1.5.0->vllm)
#   Downloading mistral_common-1.5.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm) (0.8.0)
# Collecting compressed-tensors==0.9.0 (from vllm)
#   Downloading compressed_tensors-0.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting depyf==0.18.0 (from vllm)
#   Downloading depyf-0.18.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from vllm) (3.1.1)
# Collecting ray>=2.9 (from ray[default]>=2.9->vllm)
#   Downloading ray-2.41.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting nvidia-ml-py>=12.560.30 (from vllm)
#   Downloading nvidia_ml_py-12.570.86-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.5.1+cu124)
# Requirement already satisfied: torchaudio==2.5.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (2.5.1+cu124)
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (from vllm) (0.20.1+cu124)
# Collecting xformers==0.0.28.post3 (from vllm)
#   Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting astor (from depyf==0.18.0->vllm)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting dill (from depyf==0.18.0->vllm)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting interegular (from outlines==0.1.11->vllm)
#   Downloading interegular-0.3.3-py37-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (3.1.5)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (1.6.0)
# Collecting diskcache (from outlines==0.1.11->vllm)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: referencing in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (0.36.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from outlines==0.1.11->vllm) (4.23.0)
# Collecting pycountry (from outlines==0.1.11->vllm)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting airportsdata (from outlines==0.1.11->vllm)
#   Downloading airportsdata-20241001-py3-none-any.whl.metadata (8.9 kB)
# Collecting outlines_core==0.1.26 (from outlines==0.1.11->vllm)
#   Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1->vllm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1->vllm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1->vllm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1->vllm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1->vllm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1->vllm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1->vllm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1->vllm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1->vllm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1->vllm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.5.1->vllm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.5.1->vllm) (1.3.0)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lm-format-enforcer<0.11,>=0.10.9->vllm) (24.2)
# Collecting pillow (from vllm)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting tiktoken>=0.6.0 (from vllm)
#   Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral_common[opencv]>=1.5.0->vllm) (4.11.0.86)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm) (2.27.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (8.1.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->ray[default]>=2.9->vllm) (1.5.0)
# Collecting aiohttp-cors (from ray[default]>=2.9->vllm)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default]>=2.9->vllm)
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting opencensus (from ray[default]>=2.9->vllm)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (7.1.0)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default]>=2.9->vllm)
#   Downloading virtualenv-20.29.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting py-spy>=0.2.0 (from ray[default]>=2.9->vllm)
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default]>=2.9->vllm) (1.70.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (25.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->vllm) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.19.1->vllm) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.2->vllm) (0.5.2)
# Collecting pybind11 (from xgrammar>=0.1.6->vllm)
#   Downloading pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.6->vllm) (8.3.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->vllm) (3.21.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]->vllm)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->vllm)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->vllm)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->vllm)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm) (14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.52.0->vllm) (1.0.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->outlines==0.1.11->vllm) (0.22.3)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]>=2.9->vllm) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->outlines==0.1.11->vllm) (3.0.2)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default]>=2.9->vllm)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six~=1.16 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (1.17.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default]>=2.9->vllm) (2.19.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->xgrammar>=0.1.6->vllm) (1.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open->ray[default]>=2.9->vllm) (1.17.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (2.27.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=2.9->vllm) (0.6.1)
# Downloading vllm-0.7.1-cp38-abi3-manylinux1_x86_64.whl (264.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.2/264.2 MB 8.6 MB/s eta 0:00:00
# Downloading compressed_tensors-0.9.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.8 MB/s eta 0:00:00
# Downloading depyf-0.18.0-py3-none-any.whl (38 kB)
# Downloading gguf-0.10.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.7 MB/s eta 0:00:00
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.8 MB/s eta 0:00:00
# Downloading outlines-0.1.11-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 9.4 MB/s eta 0:00:00
# Downloading xformers-0.0.28.post3-cp311-cp311-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 105.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.2 MB/s eta 0:00:00
# Downloading outlines_core-0.1.26-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 31.1 MB/s eta 0:00:00
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.0 MB/s eta 0:00:00
# Downloading lm_format_enforcer-0.10.9-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 4.5 MB/s eta 0:00:00
# Downloading mistral_common-1.5.2-py3-none-any.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 103.8 MB/s eta 0:00:00
# Downloading nvidia_ml_py-12.570.86-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.3 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 111.9 MB/s eta 0:00:00
# Downloading prometheus_fastapi_instrumentator-7.0.2-py3-none-any.whl (18 kB)
# Downloading ray-2.41.0-cp311-cp311-manylinux2014_x86_64.whl (67.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 35.7 MB/s eta 0:00:00
# Downloading tiktoken-0.7.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.4 MB/s eta 0:00:00
# Downloading transformers-4.48.2-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 123.5 MB/s eta 0:00:00
# Downloading xgrammar-0.1.11-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (396 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.9/396.9 kB 35.9 MB/s eta 0:00:00
# Downloading blake3-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 34.8 MB/s eta 0:00:00
# Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 22.6 MB/s eta 0:00:00
# Downloading partial_json_parser-0.2.1.1.post5-py3-none-any.whl (10 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 39.4 MB/s eta 0:00:00
# Downloading interegular-0.3.3-py37-none-any.whl (23 kB)
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 99.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.4 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 102.1 MB/s eta 0:00:00
# Downloading virtualenv-20.29.1-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 115.4 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 42.2 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading airportsdata-20241001-py3-none-any.whl (912 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 912.7/912.7 kB 60.3 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 21.0 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 14.0 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.4 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 13.4 MB/s eta 0:00:00
# Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 23.9 MB/s eta 0:00:00
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 121.3 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.4 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 38.5 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Installing collected packages: py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, blake3, virtualenv, uvloop, uvicorn, python-dotenv, pycountry, pybind11, pillow, partial-json-parser, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, msgspec, lark, interegular, httptools, gguf, diskcache, dill, astor, airportsdata, watchfiles, tiktoken, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, depyf, prometheus-fastapi-instrumentator, nvidia-cusolver-cu12, lm-format-enforcer, fastapi, aiohttp-cors, transformers, ray, outlines_core, opencensus, mistral_common, xgrammar, xformers, outlines, compressed-tensors, vllm
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
# Successfully installed aiohttp-cors-0.7.0 airportsdata-20241001 astor-0.8.1 blake3-1.0.4 colorful-0.5.6 compressed-tensors-0.9.0 depyf-0.18.0 dill-0.3.9 diskcache-5.6.3 distlib-0.3.9 fastapi-0.115.8 gguf-0.10.0 httptools-0.6.4 interegular-0.3.3 lark-1.2.2 lm-format-enforcer-0.10.9 mistral_common-1.5.2 msgspec-0.19.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-ml-py-12.570.86 nvidia-nvjitlink-cu12-12.4.127 opencensus-0.11.4 opencensus-context-0.1.3 outlines-0.1.11 outlines_core-0.1.26 partial-json-parser-0.2.1.1.post5 pillow-10.4.0 prometheus-fastapi-instrumentator-7.0.2 py-spy-0.4.0 pybind11-2.13.6 pycountry-24.6.1 python-dotenv-1.0.1 ray-2.41.0 starlette-0.45.3 tiktoken-0.7.0 transformers-4.48.2 uvicorn-0.34.0 uvloop-0.21.0 virtualenv-20.29.1 vllm-0.7.1 watchfiles-1.0.4 xformers-0.0.28.post3 xgrammar-0.1.11

# %%
# !pip install flash-attn
# Out:
# Collecting flash-attn
#   Using cached flash_attn-2.7.4.post1.tar.gz (6.0 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from flash-attn) (2.5.1+cu124)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash-attn) (0.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->flash-attn) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->flash-attn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->flash-attn) (3.0.2)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.7.4.post1-cp311-cp311-linux_x86_64.whl size=187815463 sha256=d944fc7d2f962bce83fc4708c2fc0c21eaf8255962a0b350ae919362a51b7ef2
#   Stored in directory: /root/.cache/pip/wheels/3d/88/d8/284b89f56af7d5bf366b10d6b8e251ac8a7c7bf3f04203fb4f
# Successfully built flash-attn
# Installing collected packages: flash-attn
# Successfully installed flash-attn-2.7.4.post1

# %%
from vllm import LLM, SamplingParams
# Out:
# INFO 02-02 16:30:11 __init__.py:183] Automatically detected platform cuda.

# %%
??LLM

# %%
llm = LLM(model="deepseek-ai/DeepSeek-R1-Distill-Llama-8B")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# INFO 02-02 16:30:27 config.py:526] This model supports multiple tasks: {'score', 'reward', 'embed', 'classify', 'generate'}. Defaulting to 'generate'.
# WARNING 02-02 16:30:27 arg_utils.py:1119] Chunked prefill is enabled by default for models with max_model_len > 32K. Currently, chunked prefill might not work with some features or models. If you encounter any issues, please disable chunked prefill by setting --enable-chunked-prefill=False.
# INFO 02-02 16:30:27 config.py:1538] Chunked prefill is enabled with max_num_batched_tokens=2048.
# INFO 02-02 16:30:27 llm_engine.py:232] Initializing a V0 LLM engine (v0.7.1) with config: model='deepseek-ai/DeepSeek-R1-Distill-Llama-8B', speculative_config=None, tokenizer='deepseek-ai/DeepSeek-R1-Distill-Llama-8B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=131072, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='xgrammar'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=deepseek-ai/DeepSeek-R1-Distill-Llama-8B, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=False, chunked_prefill_enabled=True, use_async_output_proc=True, disable_mm_preprocessor_cache=False, mm_processor_kwargs=None, pooler_config=None, compilation_config={"splitting_ops":[],"compile_sizes":[],"cudagraph_capture_sizes":[256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"max_capture_size":256}, use_cached_outputs=False,
# tokenizer_config.json:   0%|          | 0.00/3.06k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# INFO 02-02 16:30:30 cuda.py:235] Using Flash Attention backend.
# INFO 02-02 16:30:31 model_runner.py:1111] Starting to load model deepseek-ai/DeepSeek-R1-Distill-Llama-8B...
# INFO 02-02 16:30:32 weight_utils.py:251] Using model weights format ['*.safetensors']
# model-00002-of-000002.safetensors:   0%|          | 0.00/7.39G [00:00<?, ?B/s]
# model-00001-of-000002.safetensors:   0%|          | 0.00/8.67G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 02-02 16:34:04 model_runner.py:1116] Loading model weights took 14.9888 GB
# INFO 02-02 16:34:05 worker.py:266] Memory profiling takes 1.09 seconds
# INFO 02-02 16:34:05 worker.py:266] the current vLLM instance can use total_gpu_memory (39.56GiB) x gpu_memory_utilization (0.90) = 35.60GiB
# INFO 02-02 16:34:05 worker.py:266] model weights take 14.99GiB; non_torch_memory takes 0.09GiB; PyTorch activation peak memory takes 1.19GiB; the rest of the memory reserved for KV Cache is 19.33GiB.
# INFO 02-02 16:34:05 executor_base.py:108] # CUDA blocks: 9898, # CPU blocks: 2048
# INFO 02-02 16:34:05 executor_base.py:113] Maximum concurrency for 131072 tokens per request: 1.21x
# INFO 02-02 16:34:07 model_runner.py:1435] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI. If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# Capturing CUDA graph shapes: 100%|██████████| 35/35 [00:26<00:00,  1.34it/s]
# INFO 02-02 16:34:33 model_runner.py:1563] Graph capturing finished in 26 secs, took 0.26 GiB
# INFO 02-02 16:34:34 llm_engine.py:429] init engine (profile, create kv cache, warmup model) took 29.99 seconds

# %%
prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]
sampling_params = SamplingParams(temperature=0.8, top_p=0.95, max_tokens=3000)

# %%
# !pip install ipython-autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (75.1.0)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.13)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.19.2

# %%
# %load_ext autotime
outputs = llm.generate(prompts, sampling_params)

# Print the outputs.
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
# Out:
# Processed prompts: 100%|██████████| 4/4 [00:17<00:00,  4.27s/it, est. speed input: 1.52 toks/s, output: 228.00 toks/s]
# Prompt: 'Hello, my name is', Generated text: ' Helen and I want to become a professional makeup artist. I have a background in fashion design and I\'m now looking to transition into makeup artistry. I want to create a portfolio that showcases my skills and creativity. Let me think about how to approach this.\n\nFirst, I need to figure out what kind of portfolio I should create. Should it be a traditional book, an online gallery, or both? Well, since I\'m just starting out, maybe an online gallery would be more accessible. I can share it on social media and my website. But I also want something tangible to show potential clients, so maybe a printed book would be good too.\n\nNext, I need to decide on the themes and styles of the portfolio. Since I have a fashion background, incorporating high fashion looks would be great. I should include a variety of makeup styles—like beauty, theater, and special effects. Maybe I can categorize my work to make it easier for people to navigate.\n\nI should also consider the quality of the photos. I don\'t have professional photography equipment, but I can use my smartphone or ask a friend who has good camera skills. Natural lighting is important, so I need to make sure the photos are well-lit. Maybe I can do a photoshoot in my natural light during the day or set up a makeshift studio with some lighting if possible.\n\nWhat about the content? I should include a variety of looks—maybe 20-30 images in each category. That way, it shows my range. Each image should have a title or a short description to explain the look. For example, "Smoky Eye for a Glamour Shoot," "Arabian Nights Party Makeup," "Theater foundations," etc.\n\nI also need to think about my personal style. How do I want my portfolio to reflect me as an artist? Maybe a cohesive color scheme or a specific aesthetic. I should look at other makeup artists\' portfolios for inspiration but make sure my work is distinct and original.\n\nAnother thing is the layout. If it\'s a book, I should have a clear structure—maybe a cover page, an introduction, followed by sections for each category. If it\'s online, I can use a website builder that allows for easy navigation and responsive design so it looks good on all devices.\n\nI should also include a resume or bio section. This will help anyone viewing my portfolio understand my background and what I bring to the table. I can mention my fashion design experience as an advantage in creating cohesive makeup looks.\n\nWait, but how much should I include from my fashion background? Maybe the way I approach colors and textures is similar, which can translate well into makeup. I can highlight that in my bio or resume.\n\nI\'m a bit unsure about the styling of the portfolio. Should it be minimalistic, edgy, or elegant? Since I\'m aiming for high fashion, maybe something more elegant and sophisticated would be better. But I don\'t want it to look too stuffy. Maybe a clean and modern layout with a touch of creativity.\n\nAlso, I need to ensure that the images are of high quality. If I\'m taking the photos myself, I should know the best times for lighting and maybe invest in some basic lighting equipment like a reflector or a light box. Natural light is great, but sometimes it\'s hard to get the right angles.\n\nWhat about including a video portfolio? I\'m not sure if that\'s too much. It might be nice to show the transformation process or a makeup tutorial, but it could take more time and resources. Maybe focus on the still photos first and consider video later.\n\nI should also think about the audience. Potential clients or collaborators will be looking for diverse skills and creativity. By showcasing different styles, I can appeal to a broader audience. Maybe include some behind-the-scenes shots to show my process and attention to detail.\n\nI need to make sure the portfolio is updated regularly. As I take on more projects or practice more, I should add new images to keep it current. It\'s important to  ...
# Prompt: 'The president of the United States is', Generated text: " the leader of the country, and their job is to make decisions that affect millions of people. The role requires a lot of responsibility, so it's important to understand what makes someone a good fit for the presidency. Here are some key traits that are often considered essential for a successful president.\n\n1. **Leadership Skills**: A president needs to be able to lead the country in the right direction. This means having a clear vision and being able to inspire others to work toward that vision. Good leadership also involves making tough decisions and communicating effectively with people from all backgrounds.\n\n2. **Ethical Standards**: The president should be someone of high integrity and moral character. They need to uphold the values of the country and ensure that their actions and decisions align with those values. This includes being transparent and accountable for their actions.\n\n3. **Political Acumen**: The presidency is a political office, so it's crucial for the president to have a strong understanding of politics, both in terms of policy and public relations. They need to navigate complex political landscapes, build coalitions, and manage relationships with Congress, the judiciary, and the public.\n\n4. **Empathy and Compassion**: A good president should care about the people they are leading and understand their struggles. This empathy can help in creating policies that are more responsive to the needs of the population. It also fosters trust and credibility.\n\n5. **Communication Skills**: The ability to communicate effectively is key in any leadership role. The president must be able to articulate their vision clearly and persuasively, whether they're speaking to a large audience, addressing Congress, or engaging in debates.\n\n6. **Resilience and Stamina**: The presidency is a demanding job that requires long hours and constant attention to detail. A resilient leader can bounce back from setbacks and keep pushing forward toward their goals, even in the face of significant obstacles.\n\n7. **Problem-Solving Skills**: A president must be able to analyze issues, identify the root causes, and come up with effective solutions. This requires critical thinking, creativity, and the ability to adapt strategies as circumstances change.\n\n8. **Commitment to Service**: The role of the president is to serve the people, not to seek personal gain. A genuine commitment to public service is essential, as well as a willingness to put the needs of the nation above one's own interests.\n\n9. **Adaptability**: The political landscape is always changing, and a good president must be able to adapt to new challenges and evolving circumstances. This includes being open to new ideas and willing to adjust policies or strategies as needed.\n\n10. **Integrity and Loyalty**: The president should be someone who can be trusted to uphold the best interests of the country and remain loyal to their principles and the people they serve.\n\nThese traits, when combined with a strong work ethic and a deep understanding of the issues facing the nation, are essential for a successful and effective presidency.\n</think>\n\n**Essential Traits for a Successful Presidency**\n\n1. **Leadership Skills**: The ability to lead with a clear vision, inspire others, and make tough decisions is crucial for guiding the country effectively.\n\n2. **Ethical Standards**: High integrity and moral character are essential to uphold the nation's values and ensure accountability.\n\n3. **Political Acumen**: A strong understanding of politics, policy, and public relations is necessary to navigate political landscapes and build coalitions.\n\n4. **Empathy and Compassion**: Caring for the populace and understanding their struggles can lead to responsive policies and foster trust.\n\n5. **Communication Skills**: Clear and persuasive communication is key to articulating a vision and engaging with various a ...
# Prompt: 'The capital of France is', Generated text: " Paris. The capital of the United States is Washington, D. C. The capital of Japan is Tokyo. The capital of China is Beijing. The capital of Canada is Ottawa. The capital of South Korea is Seoul. The capital of Brazil is Rio de Janeiro. The capital of Germany is Berlin. The capital of the United Kingdom is London. The capital of Italy is Rome. The capital of Russia is Moscow. The capital of Australia is Sydney.\n\nAlright, so I have this list of capital cities for various countries. Let me see if I can recall them correctly. Paris is definitely France's capital. Yeah, I'm pretty sure about that. For the US, it's Washington, D. C., but sometimes people refer to it as Washington D.C. or just Washington. I think it's Washington, D. C. when you include the district.\n\nJapan's capital is Tokyo. I remember that from school. China's capital is Beijing, which is a city I've heard about a lot. Canada's capital is Ottawa. I think that's right; it's a city in Ontario, isn't it? South Korea's capital is Seoul. Yeah, that sounds familiar. Brazil's capital is Rio de Janeiro. I think that's correct, but I also remember that Brazil's government is moving to Brasília. Maybe that's something to note, but for now, the question is about the current capital.\n\nGermany's capital is Berlin. That's right; after the fall of the Berlin Wall, Berlin became the capital again. The United Kingdom's capital is London. Definitely. Italy's capital is Rome. That one is pretty famous. Russia's capital is Moscow. I'm pretty sure. Australia's capital is Sydney. Wait, isn't it Canberra? Hmm, maybe I mixed that up. Let me think. Canberra is the capital of Australia, isn't it? I might have gotten that wrong earlier.\n\nSo, I think I made a mistake with Australia. It's Canberra, not Sydney. So I need to correct that. Let me check the rest again. France – Paris, yes. United States – Washington, D. C. Japan – Tokyo, correct. China – Beijing. Canada – Ottawa. South Korea – Seoul. Brazil – Rio de Janeiro. Germany – Berlin. UK – London. Italy – Rome. Russia – Moscow. Australia – Canberra. There, I fixed that.\n\nSo, if I were to present this information, I should make sure to mention Canberra instead of Sydney for Australia. The rest seems correct. I can also add a note that Brazil is moving its government to Brasília, but the capital remains Rio de Janeiro for now. Maybe that adds some context.\n\nAnother thought: capitals are often political and historical centers. For example, London is both the capital and the largest city in the UK. Similarly, Paris is the capital and a major cultural hub. Canberra was specifically chosen as Australia's capital because it's geographically central, which makes administrative sense. Tokyo is not only the capital but also the largest city in Japan. \n\nI wonder what the capitals of other countries are. For instance, India's capital is New Delhi. Mexico's is Mexico City. I think Spain's capital is Madrid. Maybe I can explore more capitals later, but for now, I have this list down, except for Australia, where I need to correct Sydney to Canberra.\n\nI also remember that some countries have multiple capitals, but I think most have just one. For example, some places might have a capital for the country and another for a region, but in the cases listed here, they all seem to have one main capital.\n\nWait, what about countries with multiple capitals? I think some African countries have more than one capital, but I'm not sure. Maybe that's getting too detailed for now. Let me stick to the list given.\n\nIn summary, the capitals I listed are correct except for Australia, where Sydney was incorrect and Canberra is the right capital. I should make sure to double-check any facts I'm unsure about, maybe refer to a reliable source or my notes to confirm.\n\nAnother point: the spelling of the capitals is important too. For Washington, it's Washington, D. C., with the comma and the 'D' for the di ...
# Prompt: 'The future of AI is', Generated text: ' in the hands of a group of young developers and researchers, who are experimenting with new ways to make AI more accessible, inclusive, and ethical.\nThey have been working on a project called "AI for All," which focuses on building AI tools that can be used by anyone, regardless of their technical background. The goal is to create simple, user-friendly AI applications that can solve everyday problems, from helping with homework to assisting with decision-making in business.\n\nOne of the key aspects of their work is ensuring that AI systems are fair and unbiased. They are developing techniques to detect and mitigate bias in AI algorithms, which is crucial as AI systems often inherit biases from the data they are trained on.\n\nThe project also emphasizes the importance of transparency. They are working on making AI systems more interpretable, so users can understand how decisions are made and why certain outputs are generated.\n\nAdditionally, they are exploring the potential of AI to improve education and healthcare. For example, they are creating AI-powered tutoring systems that can provide personalized learning experiences for students, and AI-driven healthcare tools that can assist doctors in diagnosing diseases and managing treatment plans.\n\nThe team is also looking into ways to make AI more energy-efficient, as the environmental impact of AI systems is a growing concern. They are experimenting with new algorithms that consume less power while maintaining performance.\n\nMoreover, they are investigating the use of AI in creative fields, such as music composition and visual art. By developing AI tools that can generate music and art, they are exploring the intersection of technology and creativity, opening up new possibilities for artists and musicians.\n\nIn summary, the "AI for All" project is a comprehensive effort aimed at developing AI technologies that are not only powerful but also accessible, fair, transparent, and sustainable. The young developers and researchers behind this initiative are committed to ensuring that the benefits of AI are available to everyone, fostering a more inclusive and equitable society.\n</think>\n\n**AI for All: A Visionary Initiative**\n\n**Introduction:**\nThe "AI for All" project, spearheaded by a dedicated team of young developers and researchers, envisions a future where AI is democratized, accessible to all, and tailored to serve the needs of a diverse society. This initiative is about more than just technology; it\'s a movement towards inclusivity, equity, and ethical AI development.\n\n**Key Pillars of the Project:**\n\n1. **Accessibility and Usability:**\n   - **Democratizing AI:** The project focuses on creating user-friendly AI tools designed for anyone, regardless of technical expertise. This includes applications that assist with everyday tasks, such as homework help, decision-making in business, and personal productivity.\n\n2. **Bias Mitigation and Fairness:**\n   - **Detecting and Reducing Bias:** A critical aspect of their work is ensuring AI systems are free from bias. They employ techniques to identify and correct biases inherent in datasets, striving for fair and equitable AI outcomes.\n\n3. **Transparency and Interpretability:**\n   - **Enhancing Understanding:** The team is committed to making AI systems transparent. Their efforts focus on creating interpretable AI, allowing users to grasp decision-making processes and outputs, fostering trust and accountability.\n\n4. **AI for Education and Healthcare:**\n   - **Educational Support:** Development of AI-powered tutoring systems that offer personalized learning experiences, bridging gaps in education.\n   - **Healthcare Innovation:** AI tools assisting healthcare professionals in diagnostics and treatment management, enhancing patient care and operational efficiency.\n\n5. **Sustainability and Energy Efficiency:**\n   - **Environmental Impact:** The team explores ener ...
# time: 17.1 s (started: 2025-02-02 16:34:38 +00:00)

# %%
??llm.generate
# Out:
# time: 13.4 ms (started: 2024-05-07 14:45:21 +00:00)

# %%
??SamplingParams
# Out:
# time: 38 ms (started: 2024-05-07 14:45:21 +00:00)

# %%
sampling_params = SamplingParams(temperature=0.1, top_p=0.45, max_tokens=3000)
# Out:
# time: 364 µs (started: 2025-02-02 16:35:31 +00:00)

# %%
prompt = """

You are a medical curator and you are extracting all kinds of dates from below charts to hide personal information (Deidentification of medical charts). Extract the dates and give an output in the form of a json.

Things to keep in mind while extracting dates:

1. Consider dates without year or even a month as well
2. If a date is repeated in different form extract that as well, for example, 1st of April is written and April 1st somewhere else in the chart, then also extract it
3. Extract them exactly as mentioned in the chart, do not modify, for example, if a date is written as 1st of April, extract `1st of April`, don't change it to date format, if just day is written like 14th then extract just 14th
4. Don't add any explanation or any other text

Json output should look like this:

{{
  "dates":['date 1', 'date 2', ...]
}}

Patient chart is given below in backticks.

```
113416550
PRGH
13523357
630190
6/7/1999 12:00:00 AM
Discharge Summary
Signed
DIS
Admission Date :
06/07/1999
Report Status :
Signed
Discharge Date :
06/13/1999
HISTORY OF PRESENT ILLNESS :
Essentially , Mr. Cornea is a 60 year old male who noted the onset of dark urine during early January .
He underwent CT and ERCP at the Lisonatemi Faylandsburgnic, Community Hospital with a stent placement and resolution of jaundice .
He underwent an ECHO and endoscopy at Ingree and Ot of Weamanshy Medical Center on April 28 .
He was found to have a large , bulging , extrinsic mass in the lesser curvature of his stomach .
Fine needle aspiration showed atypical cells , positively reactive mesothelial cells .
Abdominal CT on April 14 , showed a 12 x 8 x 8 cm mass in the region of the left liver , and appeared to be from the lesser curvature of the stomach or left liver .
He denied any nausea , vomiting , anorexia , or weight loss .
He states that his color in urine or in stool is now normal .
PAST MEDICAL HISTORY :
He has hypertension and nephrolithiasis .
PAST SURGICAL HISTORY :
Status post left kidney stones x2 , and he has had a parathyroid surgery .
ALLERGIES :
He has no known drug allergies .
MEDICATIONS PRIOR TO ADMISSION :
Hydrochlorothiazide 25 mg q.d. , Clonidine 0.1 mg p.o. q.d. , baclofen 5 mg p.o. t.i.d.
HOSPITAL COURSE :
Basically , patient underwent a subtotal gastrectomy on the 7th of June by Dr. Kotefooksshuff .
He had an uncomplicated postoperative course and he was transferred .
Advanced his diet on postop day # 4 to a transitional diet .
His PCA was discontinued on postop day # 4 , and essentially he was started on his pre-op medications on the postop day # 5 .
PHYSICAL EXAMINATION :
CHEST :
Clear .
HEART :
Regular .
ABDOMINAL INCISION :
Clean , dry and intact .
No drainage .
VITAL SIGNS :
He is afebrile and otherwise vital signs are stable .
He is having good p.o. intake on present diet and he is moving his bowels .
DISPOSITION :
He is going to a rehabilitation facility until he is able to live independently .
DISCHARGE MEDICATIONS :
Same as pre-op , with the addition of Roxicet elixir .
Dictated By :
THAMETO DOYLE , M.D. OS43
Attending :
PRO R. KOTEFOOKSSHUFF , M.D. RF6 ZY525/1920
Batch :
69874
Index No. YFKAJTRZX9
D :
06/13/99
T :
06/13/99 KE9
```

"""
# Out:
# time: 500 µs (started: 2025-02-02 16:35:33 +00:00)

# %%
# %load_ext autotime

outputs = llm.generate([prompt], sampling_params)
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# Processed prompts: 100%|██████████| 1/1 [00:07<00:00,  7.31s/it, est. speed input: 117.75 toks/s, output: 67.97 toks/s]
# time: 7.32 s (started: 2025-02-02 16:35:36 +00:00)

# %%
outputs[0].outputs[0].text
# Out:
# 'Alright, so I need to extract all the dates from this patient chart and format them into a JSON array. Let me go through the chart step by step.\n\nFirst, I see the admission date is written as "06/07/1999" and also mentioned as "6/7/1999 12:00:00 AM". I should include both of these as separate entries.\n\nNext, the discharge date is clearly stated as "06/13/1999" and also appears as "06/13/99". I\'ll add both of these as well.\n\nLooking through the history of present illness, there\'s a mention of "April 28" and "April 14". These are important dates, so I\'ll extract "April 28" and "April 14".\n\nIn the hospital course section, the patient underwent surgery on the "7th of June". I\'ll note that as "7th of June".\n\nI should also check if there are any other dates. Scanning through, I see "January" mentioned, but it\'s just the month, so I don\'t have a specific date there. Similarly, other sections mention times like "12:00:00 AM" but those are times, not dates.\n\nI need to make sure I\'m capturing all instances, even if the same date is written differently. For example, "06/07/1999" and "6/7/1999" are both included.\n\nI\'ll list them all out:\n\n- "06/07/1999"\n- "6/7/1999 12:00:00 AM"\n- "06/13/1999"\n- "06/13/99"\n- "April 28"\n- "April 14"\n- "7th of June"\n\nNow, I\'ll format these into a JSON array as specified.\n\nI should double-check to ensure I haven\'t missed any dates. Going through the chart again, I confirm that these are all the dates present.\n\nFinally, I\'ll structure the JSON with a key "dates" and the array of date strings as the value.\n\n**Final Answer**\n```json\n{\n  "dates": ["06/07/1999", "6/7/1999 12:00:00 AM", "06/13/1999", "06/13/99", "April 28", "April 14", "7th of June"]\n}\n```'
# time: 2.41 ms (started: 2025-02-02 16:35:49 +00:00)

# %%
text = outputs[0].outputs[0].text
# Out:
# time: 339 µs (started: 2025-02-02 16:36:21 +00:00)

# %%
import re
import json
# Regex patterns:
# 1. Pattern for JSON blocks delimited by ```json ... ```
pattern_with_ticks = r"```json\s*(\{.*?\})\s*```"

# 2. Pattern for JSON blocks without ```json delimiters.
#    This will try to capture any substring that starts with { and ends with }.
#    (Be cautious: this regex may overmatch in complex texts.)
pattern_without_ticks = r"(\{[\s\S]*?\})"

# Find matches using finditer so we can capture the starting index
matches = []

for m in re.finditer(pattern_with_ticks, text, re.DOTALL):
    matches.append((m.start(), m.group(1)))

for m in re.finditer(pattern_without_ticks, text, re.DOTALL):
    # Exclude matches that are already captured by pattern_with_ticks.
    # Here we check that the match doesn't start with "```json" to avoid duplicates.
    if not text[max(0, m.start()-7):m.start()] == "```json":
        matches.append((m.start(), m.group(1)))

# If any JSON blocks are found, sort them by their position and select the last one.
if matches:
    matches.sort(key=lambda x: x[0])
    last_json_str = matches[-1][1]
    try:
        # Validate that the string is valid JSON
        data = json.loads(last_json_str)
        print(json.dumps(data, indent=2))
    except json.JSONDecodeError as e:
        print("Error decoding JSON:", e)
        print("Last JSON block content:", last_json_str)
else:
    print("No JSON blocks found.")
# Out:
# {
#   "dates": [
#     "06/07/1999",
#     "6/7/1999 12:00:00 AM",
#     "06/13/1999",
#     "06/13/99",
#     "April 28",
#     "April 14",
#     "7th of June"
#   ]
# }
# time: 1.63 ms (started: 2025-02-02 16:36:25 +00:00)
