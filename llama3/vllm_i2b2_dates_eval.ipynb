# %%
# !pip install vllm flash-attn huggingface_hub ipython-autotime --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.9/146.9 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 70.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 91.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 43.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 MB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 6.1 MB/s eta 0:00:00
# ...

# %%
# !pip install outlines --upgrade --quiet

# %%
# %load_ext autotime
from huggingface_hub import notebook_login

notebook_login()
# Out:
# ...
# time: 257 ms (started: 2024-07-06 06:48:04 +00:00)

# %%
# !git clone https://github.com/shashj/bioner-jupyter-collection.git
# Out:
# Cloning into 'bioner-jupyter-collection'...
# remote: Enumerating objects: 271, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 271 (delta 43), reused 56 (delta 22), pack-reused 188
# Receiving objects: 100% (271/271), 2.31 MiB | 9.19 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# time: 1.21 s (started: 2024-07-06 06:57:30 +00:00)

# %%
# %cd /content/bioner-jupyter-collection/llama3/
# Out:
# /content/bioner-jupyter-collection/llama3
# time: 1.62 ms (started: 2024-07-06 06:57:35 +00:00)

# %%
# !pwd
# Out:
# /content/bioner-jupyter-collection/llama3
# time: 105 ms (started: 2024-07-06 06:57:39 +00:00)

# %%
# !python i2b2_date_eval.py
# Out:
# WARNING 07-06 07:28:07 config.py:1354] Casting torch.bfloat16 to torch.float16.
# INFO 07-06 07:28:07 llm_engine.py:169] Initializing an LLM engine (v0.5.1) with config: model='meta-llama/Meta-Llama-3-8B-Instruct', speculative_config=None, tokenizer='meta-llama/Meta-Llama-3-8B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, rope_scaling=None, rope_theta=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=8192, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None), seed=0, served_model_name=meta-llama/Meta-Llama-3-8B-Instruct, use_v2_block_manager=False, enable_prefix_caching=False)
# ...

# %%
from outlines_schemas import ExpectedJSONOutputFormat_Dates
import pickle

# %% [markdown]
# ## Matching predicted NER

# %%
with open("results_dates/train_date_results.pkl", 'rb') as f:
    dates_results = pickle.load(f)

# %%
dates_results['648']
# Out:
# ExpectedJSONOutputFormat_Dates(dates=['03/25/2002', '03/29/2002', '03/29/02', '03/27', '05/22/02', '03/28', '03/31', '03/31/02'])

# %%
with open("../datasets/i2b2/train_jsons/all_records_train.pkl", 'rb') as f:
    ground_truth_records = pickle.load(f)

# %%
filtered_dict = {key: [item['TEXT'] for item in value if item['TYPE'] == 'DATE'] for key, value in ground_truth_records.items()}

# %%
filtered_dict['648']
# Out:
# ['3/25',
#  '03/25',
#  '03/29',
#  '03/29',
#  '03/29',
#  '05/22',
#  '3/27',
#  '3/27',
#  '3/28',
#  '3/28',
#  '3/31',
#  '3/31',
#  '3/31',
#  '03/29']

# %%
with open("../datasets/i2b2/train_jsons/all_records_train_text.pkl", 'rb') as f:
    ground_truth_records_text = pickle.load(f)

# %%
print(ground_truth_records_text['648'])
# Out:
# 070253172
# CMC
# 43378653
# 3/25/2002 12:00:00 AM
# NSCLCA , metastatic to spine and brain
# DIS
# Admission Date :
# 03/25/2002
# Report Status :
# Discharge Date :
# 03/29/2002
# ****** DISCHARGE ORDERS ******
# MERVBENWIERST , BIE S. 056-08-55-3V96
# Room :
# 1D-419
# Service :
# HEM
# DISCHARGE PATIENT ON :
# 03/29/02 AT 02:00 PM
# CONTINGENT UPON HO evaluation
# WILL D / C ORDER BE USED AS THE D / C SUMMARY :
# YES
# Attending :
# XELLCAUGH , REYAZA RO , M.D.
# CODE STATUS :
# Full code
# DISPOSITION :
# Home w/ services
# DISCHARGE MEDICATIONS :
# DULCOLAX ( BISACODYL ) 10 MG PR QD
# HOLD IF :
# if bm already .
# DECADRON ( DEXAMETHASONE ) 6 MG PO Q6H COLACE ( DOCUSATE SODIUM ) 100 MG PO BID LACTULOSE 30 MILLILITERS PO QID MAALOX PLUS EX. STR .
# 15 milliliters PO Q6H PRN Indigestion MOM ( MAGNESIUM HYDROXIDE ) 30 milliliters PO QD PRN Constipation DILANTIN ( PHENYTOIN ) 400 MG PO QD Starting Today ( 03/29 )
# Food / Drug Interaction Instruction
# ...

# %% [markdown]
# ## Defining Eval Strategy
# ### Matching text

# %%
dates_results['648'].dict()
# Out:
# {'dates': ['03/25/2002',
#   '03/29/2002',
#   '03/29/02',
#   '03/27',
#   '05/22/02',
#   '03/28',
#   '03/31',
#   '03/31/02']}

# %%
for date in list(dates_results['648'].dict().values())[0]:
    print(date)
# Out:
# 03/25/2002
# 03/29/2002
# 03/29/02
# 03/27
# 05/22/02
# 03/28
# 03/31
# 03/31/02

# %%
[x in ground_truth_records_text['648'] for x in list(dates_results['648'].dict().values())[0]]
# Out:
# [True, True, True, False, True, False, False, False]

# %%
import re
record = '648'
[
    bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record]))
    if x[0].isdigit() and int(x[0])!=0 
    else (
        bool(re.search(rf'(\(\s*{x[1:]}\s*\)|\b{x[1:]}\b)', ground_truth_records_text[record])) | 
        bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record])) 
    )
    for x in list(dates_results[record].dict().values())[0]
]
# Out:
# [True, True, True, True, True, True, True, True]

# %%
for date in list(dates_results['649'].dict().values())[0]:
    print(date)
# Out:
# 09/18/2001
# 09/18/2001 10:52 AM
# 09/18/2001 12:00:00 AM

# %%
filtered_dict['649']
# Out:
# ['9/18', '09/18', '09/18']

# %%
import re
record = '649'
[
    bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record]))
    if x[0].isdigit() and int(x[0])!=0 
    else (
        bool(re.search(rf'(\(\s*{x[1:]}\s*\)|\b{x[1:]}\b)', ground_truth_records_text[record])) | 
        bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record])) 
    )
    for x in list(dates_results[record].dict().values())[0]
]
# Out:
# [True, True, True]

# %%
for date in list(dates_results['652'].dict().values())[0]:
    print(date)
# Out:
# 10/15/2002
# 10/20/2002
# 10/21/2002
# 10/30/2002
# 9/22/02
# March 1998
# April 2001
# 5/10
# 1st of April
# 1998

# %%
filtered_dict['652']
# Out:
# ['10/15',
#  '10/15',
#  '10/20',
#  'March',
#  'April',
#  '9/22',
#  '10/15',
#  '10/30',
#  '10/20',
#  '10/21']

# %%
record = '652'
[
    bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record]))
    if x[0].isdigit() and int(x[0])!=0 
    else (
        bool(re.search(rf'(\(\s*{x[1:]}\s*\)|\b{x[1:]}\b)', ground_truth_records_text[record])) | 
        bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record])) 
    )
    for x in list(dates_results[record].dict().values())[0]
]
# Out:
# [True, True, True, True, True, True, True, True, False, True]

# %% [markdown]
# ### Getting offsets on original text

# %%
import re

def find_match_offsets(text, pattern):
    matches = re.finditer(pattern, text)
    return [(match.start(), match.end()) for match in matches]

# Example usage:
text = "The quick brown fox jumps over the lazy dog. The fox is quick."
pattern = r"quick"

offsets = find_match_offsets(text, pattern)
print(offsets)
# Out:
# [(4, 9), (56, 61)]

# %%
## offsets for GT

results = {
    item: {
        'offsets': offsets,
        'ground_truth': item
    }
    for item in filtered_dict['652']
    if (offsets := find_match_offsets(ground_truth_records_text['652'], item))
}

# %%
results
# Out:
# {'10/15': {'offsets': [(31, 36), (186, 191), (2437, 2442)],
#   'ground_truth': '10/15'},
#  '10/20': {'offsets': [(214, 219), (4788, 4793)], 'ground_truth': '10/20'},
#  'March': {'offsets': [(719, 724)], 'ground_truth': 'March'},
#  'April': {'offsets': [(1104, 1109)], 'ground_truth': 'April'},
#  '9/22': {'offsets': [(1270, 1274)], 'ground_truth': '9/22'},
#  '10/30': {'offsets': [(4700, 4705)], 'ground_truth': '10/30'},
#  '10/21': {'offsets': [(4804, 4809)], 'ground_truth': '10/21'}}

# %% [markdown]
# ### Getting offsets on predicted

# %%
record = '652'
include_vector = [
    bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record]))
    if x[0].isdigit() and int(x[0])!=0 
    else (
        bool(re.search(rf'(\(\s*{x[1:]}\s*\)|\b{x[1:]}\b)', ground_truth_records_text[record])) | 
        bool(re.search(rf'(\(\s*{x}\s*\)|\b{x}\b)', ground_truth_records_text[record])) 
    )
    for x in list(dates_results[record].dict().values())[0]
]

# %%
final_predictions = [item for item, include in zip(list(dates_results[record].dict().values())[0], include_vector) if include]
final_predictions
# Out:
# ['10/15/2002',
#  '10/20/2002',
#  '10/21/2002',
#  '10/30/2002',
#  '9/22/02',
#  'March 1998',
#  'April 2001',
#  '5/10',
#  '1998']

# %%
## offsets for predicted

results_pred = {
    item: {
        'offsets': offsets,
        'predicted_text': item
    }
    for item in final_predictions
    if (offsets := find_match_offsets(ground_truth_records_text['652'], item))
}

# %%
results_pred
# Out:
# {'10/15/2002': {'offsets': [(31, 41), (186, 196)],
#   'predicted_text': '10/15/2002'},
#  '10/20/2002': {'offsets': [(214, 224), (4788, 4798)],
#   'predicted_text': '10/20/2002'},
#  '10/21/2002': {'offsets': [(4804, 4814)], 'predicted_text': '10/21/2002'},
#  '10/30/2002': {'offsets': [(4700, 4710)], 'predicted_text': '10/30/2002'},
#  '9/22/02': {'offsets': [(1270, 1277)], 'predicted_text': '9/22/02'},
#  'March 1998': {'offsets': [(719, 729)], 'predicted_text': 'March 1998'},
#  'April 2001': {'offsets': [(1104, 1114)], 'predicted_text': 'April 2001'},
#  '5/10': {'offsets': [(957, 961)], 'predicted_text': '5/10'},
#  '1998': {'offsets': [(653, 657), (725, 729)], 'predicted_text': '1998'}}

# %%
def calculate_precision_recall(ground_truth, predicted_text):
    true_positives = 0
    false_positives = 0
    false_negatives = 0

    # Create dictionaries mapping offsets to their corresponding text
    ground_truth_dict = {}
    for item in ground_truth.values():
        for offset in item['offsets']:
            ground_truth_dict[offset] = item['ground_truth']

    predicted_dict = {}
    for item in predicted_text.values():
        for offset in item['offsets']:
            predicted_dict[offset] = item['predicted_text']

    # Calculate true positives and false positives
    for pred_offset, pred_text in predicted_dict.items():
        pred_start, pred_end = pred_offset
        match_found = False
        for gt_offset, gt_text in ground_truth_dict.items():
            gt_start, gt_end = gt_offset
            if (pred_start <= gt_end and gt_start <= pred_end):
                # Check if the predicted text contains the ground truth text
                if gt_text in pred_text:
                    true_positives += 1
                    match_found = True
                    break
        if not match_found:
            false_positives += 1

    # Calculate false negatives
    for gt_offset, gt_text in ground_truth_dict.items():
        gt_start, gt_end = gt_offset
        match_found = False
        for pred_offset, pred_text in predicted_dict.items():
            pred_start, pred_end = pred_offset
            if (pred_start <= gt_end and gt_start <= pred_end):
                if gt_text in pred_text:
                    match_found = True
                    break
        if not match_found:
            false_negatives += 1

    # Calculate precision and recall
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

    print(f"true positives: {true_positives}, false positives: {false_positives}, false negatives: {false_negatives}")

    return precision, recall

# %%
precision, recall = calculate_precision_recall(results, results_pred)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
# Out:
# true positives: 9, false positives: 3, false negatives: 1
# Precision: 0.75
# Recall: 0.90
